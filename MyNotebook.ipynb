# %% [markdown]
# # My Pre-Filled NotebookThis notebook was created automatically using PowerShell.

# %%
import pandas as pdimport numpy as np

# %%
# Sample DataFramedf = pd.DataFrame({    'Name': ['Alice', 'Bob', 'Charlie'],    'Age': [25, 30, 35]})df

# %% [markdown]
# ## AnalysisYou can add your analysis here.
