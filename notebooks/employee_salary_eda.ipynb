# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# For nicer plots
sns.set(style="whitegrid")
# %matplotlib inline

# %%
# Load the employee salary data
data_path = "../data/employee_salary_data.csv"  # adjust path if needed
df = pd.read_csv(data_path)

# Display first few rows
df.head()
# Out:
#    EmployeeID     Name Department  Salary
# 0           1    Alice         HR   50000
# 1           2      Bob         IT   60000
# 2           3  Charlie    Finance   55000
# 3           4    Diana  Marketing   52000
# 4           5     Evan         IT   61000

# %%
# Basic info about dataset
df.info()

# Summary statistics
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  5 non-null      int64
#  1   Name        5 non-null      object
#  2   Department  5 non-null      object
#  3   Salary      5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes
#        EmployeeID        Salary
# count    5.000000      5.000000
# mean     3.000000  55600.000000
# std      1.581139   4827.007354
# min      1.000000  50000.000000
# 25%      2.000000  52000.000000
# 50%      3.000000  55000.000000
# 75%      4.000000  60000.000000
# max      5.000000  61000.000000

# %%
# Check for missing data
df.isnull().sum()
# Out:
# EmployeeID    0
# Name          0
# Department    0
# Salary        0
# dtype: int64

# %%
# Histogram of salaries
plt.figure(figsize=(8,5))
sns.histplot(df['Salary'], bins=5, kde=True)
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Count")
plt.show()

# Average salary per department
plt.figure(figsize=(8,5))
sns.barplot(x='Department', y='Salary', data=df, ci=None)
plt.title("Average Salary per Department")
plt.xlabel("Department")
plt.ylabel("Salary")
plt.show()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_8340\2724422289.py:11: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Department', y='Salary', data=df, ci=None)
